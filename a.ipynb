# %%
import os

# %%
arr_com = []
real = []
for i in os.listdir("0-13"):
    arr_com.append(i.split("_")[0])
for i in os.listdir("data/Harga Bahan Pangan/test"):
    real.append(i.split(".")[0])

# %%
arr_com = set(arr_com)
real = set(real)
print(real.difference(arr_com))
print(arr_com)
print(len(arr_com))
print(real)
print(len(real))
# Out:
# set()
# {'Gula Konsumsi', 'Bawang Merah', 'Bawang Putih Bonggol', 'Daging Sapi Murni', 'Telur Ayam Ras', 'Cabai Merah Keriting', 'Daging Ayam Ras', 'Tepung Terigu (Curah)', 'Cabai Rawit Merah', 'Minyak Goreng Curah', 'Minyak Goreng Kemasan Sederhana', 'Beras Premium', 'Beras Medium'}
# 13
# {'Gula Konsumsi', 'Bawang Merah', 'Bawang Putih Bonggol', 'Daging Sapi Murni', 'Telur Ayam Ras', 'Cabai Merah Keriting', 'Daging Ayam Ras', 'Tepung Terigu (Curah)', 'Cabai Rawit Merah', 'Minyak Goreng Curah', 'Minyak Goreng Kemasan Sederhana', 'Beras Premium', 'Beras Medium'}
# 13
