# %%
import pandas
import os

# %%
dfs = []
for i in os.listdir('0-13'):
    if i.endswith('.csv'):
        dfs.append(pandas.read_csv(f'0-13/{i}'))

df = pandas.concat(dfs)
df.to_csv('subFinal.csv', index=False)
